# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
import os
import json

def count_images(image_dir, exts={".jpg", ".jpeg", ".png", ".bmp", ".txt"}):
    image_count = 0
    for filename in os.listdir(image_dir):
        if os.path.splitext(filename.lower())[1] in exts:
            image_count += 1
    print(f"Total images: {image_count}")

count_images("/kaggle/input/lapa-face-parsing-dataset/LaPa/train/images")
count_images("/kaggle/input/lapa-face-parsing-dataset/LaPa/train/landmarks")
# Out:
# Total images: 18168
# Total images: 18168

# %%
import os
import numpy as np
import cv2
from glob import glob
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers as L
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger

# %%
def load_dataset(path):
    train_x = sorted(glob(os.path.join(path, "train", "images", "*.jpg")))
    train_y = sorted(glob(os.path.join(path, "train", "landmarks", "*.txt")))

    valid_x = sorted(glob(os.path.join(path, "val", "images", "*.jpg")))
    valid_y = sorted(glob(os.path.join(path, "val", "landmarks", "*.txt")))

    test_x = sorted(glob(os.path.join(path, "test", "images", "*.jpg")))
    test_y = sorted(glob(os.path.join(path, "test", "landmarks", "*.txt")))

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image_lankmarks(image_path, landmark_path):
    """ Image """
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    h, w, _ = image.shape
    image = cv2.resize(image, (image_w, image_h))
    image = image/255.0
    image = image.astype(np.float32)

    """ Lankmarks """
    data = open(landmark_path, "r").read()
    lankmarks = []

    for line in data.strip().split("\n")[1:]:
        x, y = line.split(" ")
        x = float(x)/w
        y = float(y)/h

        lankmarks.append(x)
        lankmarks.append(y)

    lankmarks = np.array(lankmarks, dtype=np.float32)

    return image, lankmarks

def preprocess(x, y):
    def f(x, y):
        x = x.decode()
        y = y.decode()

        image, landmarks = read_image_lankmarks(x, y)
        return image, landmarks

    image, landmarks = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
    image.set_shape([image_h, image_w, 3])
    landmarks.set_shape([num_landmarks * 2])

    return image, landmarks

def tf_dataset(x, y, batch=8):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(buffer_size=5000).map(preprocess)
    ds = ds.batch(batch).prefetch(2)
    return ds

# %%
""" Hyperparameters """
image_h = 512
image_w = 512
num_landmarks = 106
input_shape = (image_h, image_w, 3)
batch_size = 32
lr = 1e-3

""" Paths """
dataset_path = "/kaggle/input/lapa-face-parsing-dataset/LaPa/"

""" Loading the dataset """
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)
print(f"Train: {len(train_x)}/{len(train_y)} - Valid: {len(valid_x)}/{len(valid_y)} - Test: {len(test_x)}/{len(test_x)}")
print("")

# """ Dataset Pipeline """
# train_ds = tf_dataset(train_x, train_y, batch=batch_size)
# valid_ds = tf_dataset(valid_x, valid_y, batch=batch_size)
# Out:
# Train: 18168/18168 - Valid: 2000/2000 - Test: 2000/2000

# %%
# Restrict to target sizes
train_limit = 4000
val_limit = 500
test_limit = 500

train_x, train_y = train_x[:train_limit], train_y[:train_limit]
valid_x, valid_y = valid_x[:val_limit], valid_y[:val_limit]
test_x, test_y   = test_x[:test_limit], test_y[:test_limit]

print(f"Train: {len(train_x)} - Valid: {len(valid_x)} - Test: {len(test_x)}")

""" Dataset Pipeline """
train_ds = tf_dataset(train_x, train_y, batch=batch_size)
valid_ds = tf_dataset(valid_x, valid_y, batch=batch_size)
test_ds  = tf_dataset(test_x, test_y, batch=batch_size)
# Out:
# Train: 4000 - Valid: 500 - Test: 500

# %%
def build_model(input_shape, num_landmarks):
    inputs = L.Input(input_shape)

    backbone = MobileNetV2(include_top=False, weights="imagenet", input_tensor=inputs, alpha=0.5)
    backbone.trainable = True

    x = backbone.output
    x = L.GlobalAveragePooling2D()(x)
    x = L.Dropout(0.2)(x)
    outputs = L.Dense(num_landmarks*2, activation="sigmoid")(x)

    model = tf.keras.models.Model(inputs, outputs)
    return model

""" Model """
model = build_model(input_shape, num_landmarks)
model.summary()
# Out:
# /tmp/ipykernel_36/1435648425.py:4: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   backbone = MobileNetV2(include_top=False, weights="imagenet", input_tensor=inputs, alpha=0.5)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.5_224_no_top.h5
# 3201480/3201480 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 256, 256,  │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 256, 256,  │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 256, 256,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 256,  │        144 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 256,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 256, 256,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 256, 256,  │        128 │ expanded_conv_de… │
# │ (Conv2D)            │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 256, 256,  │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 256, 256,  │        384 │ expanded_conv_pr… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 256, 256,  │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 256, 256,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 257, 257,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 128, 128,  │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 128, 128,  │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 128, 128,  │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 128, 128,  │        768 │ block_1_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 128, 128,  │         64 │ block_1_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 128, 128,  │      1,536 │ block_1_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 128, 128,  │        384 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 128, 128,  │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 128, 128,  │        864 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 128, 128,  │        384 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 128, 128,  │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 128, 128,  │      1,536 │ block_2_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 128, 128,  │         64 │ block_2_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 128, 128,  │          0 │ block_1_project_… │
# │                     │ 16)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 128, 128,  │      1,536 │ block_2_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 128, 128,  │        384 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 128, 128,  │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 129, 129,  │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 64, 64,    │        864 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 64, 64,    │        384 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 64, 64,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 64, 64,    │      1,536 │ block_3_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 64, 64,    │         64 │ block_3_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 64, 64,    │      1,536 │ block_3_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 64, 64,    │        384 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 64, 64,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 64, 64,    │        864 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 64, 64,    │        384 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 64, 64,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 64, 64,    │      1,536 │ block_4_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 64, 64,    │         64 │ block_4_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 64, 64,    │          0 │ block_3_project_… │
# │                     │ 16)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 64, 64,    │      1,536 │ block_4_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 64, 64,    │        384 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 64, 64,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 64, 64,    │        864 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 64, 64,    │        384 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 64, 64,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 64, 64,    │      1,536 │ block_5_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 64, 64,    │         64 │ block_5_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 64, 64,    │          0 │ block_4_add[0][0… │
# │                     │ 16)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 64, 64,    │      1,536 │ block_5_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 64, 64,    │        384 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 64, 64,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 65, 65,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 32, 32,    │        864 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 32, 32,    │        384 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 32, 32,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 32, 32,    │      3,072 │ block_6_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 32, 32,    │        128 │ block_6_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 32, 32,    │      6,144 │ block_6_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 32, 32,    │        768 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 32, 32,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 32, 32,    │      1,728 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 32, 32,    │        768 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 32, 32,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 32, 32,    │      6,144 │ block_7_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 32, 32,    │        128 │ block_7_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 32, 32,    │          0 │ block_6_project_… │
# │                     │ 32)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 32, 32,    │      6,144 │ block_7_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 32, 32,    │        768 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 32, 32,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 32, 32,    │      1,728 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 32, 32,    │        768 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 32, 32,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 32, 32,    │      6,144 │ block_8_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 32, 32,    │        128 │ block_8_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 32, 32,    │          0 │ block_7_add[0][0… │
# │                     │ 32)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 32, 32,    │      6,144 │ block_8_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 32, 32,    │        768 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 32, 32,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 32, 32,    │      1,728 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 32, 32,    │        768 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 32, 32,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 32, 32,    │      6,144 │ block_9_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 32, 32,    │        128 │ block_9_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 32, 32,    │          0 │ block_8_add[0][0… │
# │                     │ 32)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 32, 32,    │      6,144 │ block_9_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 32, 32,    │        768 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 32, 32,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 32, 32,    │      1,728 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 32, 32,    │        768 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 32, 32,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 32, 32,    │      9,216 │ block_10_depthwi… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 32, 32,    │        192 │ block_10_project… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 32, 32,    │     13,824 │ block_10_project… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 32, 32,    │      1,152 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 32, 32,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 32, 32,    │      2,592 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 32, 32,    │      1,152 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 32, 32,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 32, 32,    │     13,824 │ block_11_depthwi… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 32, 32,    │        192 │ block_11_project… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 32, 32,    │          0 │ block_10_project… │
# │                     │ 48)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 32, 32,    │     13,824 │ block_11_add[0][… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 32, 32,    │      1,152 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 32, 32,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 32, 32,    │      2,592 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 32, 32,    │      1,152 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 32, 32,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 32, 32,    │     13,824 │ block_12_depthwi… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 32, 32,    │        192 │ block_12_project… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 32, 32,    │          0 │ block_11_add[0][… │
# │                     │ 48)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 32, 32,    │     13,824 │ block_12_add[0][… │
# │ (Conv2D)            │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 32, 32,    │      1,152 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 32, 32,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 33, 33,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 16, 16,    │      2,592 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 16, 16,    │      1,152 │ block_13_depthwi… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 16, 16,    │          0 │ block_13_depthwi… │
# │ (ReLU)              │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 16, 16,    │     23,040 │ block_13_depthwi… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 16, 16,    │        320 │ block_13_project… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 16, 16,    │     38,400 │ block_13_project… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 16, 16,    │      1,920 │ block_14_expand[… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 16, 16,    │          0 │ block_14_expand_… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 16, 16,    │      4,320 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 16, 16,    │      1,920 │ block_14_depthwi… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 16, 16,    │          0 │ block_14_depthwi… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 16, 16,    │     38,400 │ block_14_depthwi… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 16, 16,    │        320 │ block_14_project… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 16, 16,    │          0 │ block_13_project… │
# │                     │ 80)               │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 16, 16,    │     38,400 │ block_14_add[0][… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 16, 16,    │      1,920 │ block_15_expand[… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 16, 16,    │          0 │ block_15_expand_… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 16, 16,    │      4,320 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 16, 16,    │      1,920 │ block_15_depthwi… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 16, 16,    │          0 │ block_15_depthwi… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 16, 16,    │     38,400 │ block_15_depthwi… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 16, 16,    │        320 │ block_15_project… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 16, 16,    │          0 │ block_14_add[0][… │
# │                     │ 80)               │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 16, 16,    │     38,400 │ block_15_add[0][… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 16, 16,    │      1,920 │ block_16_expand[… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 16, 16,    │          0 │ block_16_expand_… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 16, 16,    │      4,320 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 16, 16,    │      1,920 │ block_16_depthwi… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 16, 16,    │          0 │ block_16_depthwi… │
# │ (ReLU)              │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 16, 16,    │     76,800 │ block_16_depthwi… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 16, 16,    │        640 │ block_16_project… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 16, 16,    │    204,800 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 16, 16,    │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 16, 16,    │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 212)       │    271,572 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 977,796 (3.73 MB)
#  Trainable params: 959,252 (3.66 MB)
#  Non-trainable params: 18,544 (72.44 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr),
    loss="binary_crossentropy",
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
    ]
)
checkpoint_filepath = "MobileNetV2_keypoints.weights.h5"

""" Training """
callbacks = [
    ModelCheckpoint(checkpoint_filepath, monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-7, verbose=1),
]

# %%
num_epochs = 50

history = model.fit(train_ds,
    validation_data=valid_ds,
    epochs=num_epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759062423.107039      98 service.cc:148] XLA service 0x7e4e18484700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759062423.108174      98 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1759062423.108193      98 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1759062426.813129      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1759062431.251027      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759062431.488359      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1759062451.830130      98 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 0.6740 - mae: 0.0551
# E0000 00:00:1759062535.949363     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759062536.150462     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 3.74726, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 153s 704ms/step - loss: 0.6740 - mae: 0.0550 - val_loss: 3.7473 - val_mae: 0.3761 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.6636 - mae: 0.0285
# Epoch 2: val_loss improved from 3.74726 to 1.56954, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 321ms/step - loss: 0.6636 - mae: 0.0285 - val_loss: 1.5695 - val_mae: 0.3205 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 0.6623 - mae: 0.0220
# Epoch 3: val_loss improved from 1.56954 to 1.32822, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - loss: 0.6623 - mae: 0.0220 - val_loss: 1.3282 - val_mae: 0.3007 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - loss: 0.6613 - mae: 0.0191
# Epoch 4: val_loss improved from 1.32822 to 0.95642, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 328ms/step - loss: 0.6613 - mae: 0.0191 - val_loss: 0.9564 - val_mae: 0.2378 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.6615 - mae: 0.0168
# Epoch 5: val_loss improved from 0.95642 to 0.85577, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6615 - mae: 0.0168 - val_loss: 0.8558 - val_mae: 0.2070 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.6610 - mae: 0.0154
# Epoch 6: val_loss improved from 0.85577 to 0.75693, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6610 - mae: 0.0154 - val_loss: 0.7569 - val_mae: 0.1578 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - loss: 0.6609 - mae: 0.0148
# Epoch 7: val_loss improved from 0.75693 to 0.68550, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 328ms/step - loss: 0.6609 - mae: 0.0148 - val_loss: 0.6855 - val_mae: 0.0821 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6609 - mae: 0.0135
# Epoch 8: val_loss did not improve from 0.68550
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - loss: 0.6609 - mae: 0.0135 - val_loss: 0.7196 - val_mae: 0.1260 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.6607 - mae: 0.0142
# Epoch 9: val_loss improved from 0.68550 to 0.67288, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6607 - mae: 0.0142 - val_loss: 0.6729 - val_mae: 0.0581 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.6608 - mae: 0.0124
# Epoch 10: val_loss improved from 0.67288 to 0.67197, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 327ms/step - loss: 0.6608 - mae: 0.0124 - val_loss: 0.6720 - val_mae: 0.0547 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.6603 - mae: 0.0127
# Epoch 11: val_loss did not improve from 0.67197
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6603 - mae: 0.0127 - val_loss: 0.6922 - val_mae: 0.0880 - learning_rate: 0.0010
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.6605 - mae: 0.0123
# Epoch 12: val_loss did not improve from 0.67197
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - loss: 0.6605 - mae: 0.0123 - val_loss: 0.6840 - val_mae: 0.0826 - learning_rate: 0.0010
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.6602 - mae: 0.0116
# Epoch 13: val_loss did not improve from 0.67197
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 323ms/step - loss: 0.6602 - mae: 0.0116 - val_loss: 0.6781 - val_mae: 0.0745 - learning_rate: 0.0010
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.6603 - mae: 0.0105
# Epoch 14: val_loss improved from 0.67197 to 0.66675, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 325ms/step - loss: 0.6603 - mae: 0.0105 - val_loss: 0.6668 - val_mae: 0.0431 - learning_rate: 1.0000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6604 - mae: 0.0099
# Epoch 15: val_loss improved from 0.66675 to 0.66344, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - loss: 0.6604 - mae: 0.0099 - val_loss: 0.6634 - val_mae: 0.0292 - learning_rate: 1.0000e-04
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.6602 - mae: 0.0096
# Epoch 16: val_loss improved from 0.66344 to 0.66230, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6602 - mae: 0.0096 - val_loss: 0.6623 - val_mae: 0.0229 - learning_rate: 1.0000e-04
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.6601 - mae: 0.0097
# Epoch 17: val_loss improved from 0.66230 to 0.66163, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6601 - mae: 0.0097 - val_loss: 0.6616 - val_mae: 0.0184 - learning_rate: 1.0000e-04
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.6603 - mae: 0.0094
# Epoch 18: val_loss improved from 0.66163 to 0.66113, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6603 - mae: 0.0094 - val_loss: 0.6611 - val_mae: 0.0141 - learning_rate: 1.0000e-04
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.6601 - mae: 0.0094
# Epoch 19: val_loss improved from 0.66113 to 0.66106, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 321ms/step - loss: 0.6601 - mae: 0.0094 - val_loss: 0.6611 - val_mae: 0.0136 - learning_rate: 1.0000e-04
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6602 - mae: 0.0093
# Epoch 20: val_loss improved from 0.66106 to 0.66091, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6602 - mae: 0.0093 - val_loss: 0.6609 - val_mae: 0.0120 - learning_rate: 1.0000e-04
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.6604 - mae: 0.0092
# Epoch 21: val_loss improved from 0.66091 to 0.66084, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 323ms/step - loss: 0.6604 - mae: 0.0092 - val_loss: 0.6608 - val_mae: 0.0114 - learning_rate: 1.0000e-04
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6603 - mae: 0.0093
# Epoch 22: val_loss improved from 0.66084 to 0.66075, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6603 - mae: 0.0093 - val_loss: 0.6607 - val_mae: 0.0100 - learning_rate: 1.0000e-04
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.6602 - mae: 0.0091
# Epoch 23: val_loss did not improve from 0.66075
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6602 - mae: 0.0091 - val_loss: 0.6608 - val_mae: 0.0104 - learning_rate: 1.0000e-04
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.6600 - mae: 0.0091
# Epoch 24: val_loss did not improve from 0.66075
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 321ms/step - loss: 0.6600 - mae: 0.0091 - val_loss: 0.6607 - val_mae: 0.0102 - learning_rate: 1.0000e-04
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.6605 - mae: 0.0090
# Epoch 25: val_loss did not improve from 0.66075
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6605 - mae: 0.0090 - val_loss: 0.6608 - val_mae: 0.0109 - learning_rate: 1.0000e-04
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - loss: 0.6599 - mae: 0.0091
# Epoch 26: val_loss improved from 0.66075 to 0.66068, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 329ms/step - loss: 0.6599 - mae: 0.0091 - val_loss: 0.6607 - val_mae: 0.0094 - learning_rate: 1.0000e-05
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6605 - mae: 0.0088
# Epoch 27: val_loss improved from 0.66068 to 0.66065, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - loss: 0.6605 - mae: 0.0088 - val_loss: 0.6607 - val_mae: 0.0089 - learning_rate: 1.0000e-05
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.6600 - mae: 0.0088
# Epoch 28: val_loss improved from 0.66065 to 0.66064, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - loss: 0.6601 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.6598 - mae: 0.0089
# Epoch 29: val_loss improved from 0.66064 to 0.66063, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - loss: 0.6598 - mae: 0.0089 - val_loss: 0.6606 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6603 - mae: 0.0087
# Epoch 30: val_loss improved from 0.66063 to 0.66063, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - loss: 0.6603 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0087 - learning_rate: 1.0000e-05
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.6601 - mae: 0.0087
# Epoch 31: val_loss improved from 0.66063 to 0.66060, saving model to MobileNetV2_keypoints.weights.h5
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 317ms/step - loss: 0.6601 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0083 - learning_rate: 1.0000e-05
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6603 - mae: 0.0087
# Epoch 32: val_loss improved from 0.66060 to 0.66060, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6603 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0083 - learning_rate: 1.0000e-06
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.6604 - mae: 0.0087
# Epoch 33: val_loss improved from 0.66060 to 0.66059, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - loss: 0.6604 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0082 - learning_rate: 1.0000e-06
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6603 - mae: 0.0087
# Epoch 34: val_loss improved from 0.66059 to 0.66059, saving model to MobileNetV2_keypoints.weights.h5
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6603 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0081 - learning_rate: 1.0000e-06
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.6599 - mae: 0.0088
# Epoch 35: val_loss improved from 0.66059 to 0.66059, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 320ms/step - loss: 0.6600 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0081 - learning_rate: 1.0000e-07
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.6599 - mae: 0.0088
# Epoch 36: val_loss improved from 0.66059 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 317ms/step - loss: 0.6599 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0080 - learning_rate: 1.0000e-07
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.6605 - mae: 0.0087
# Epoch 37: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-07.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 320ms/step - loss: 0.6605 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0080 - learning_rate: 1.0000e-07
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.6601 - mae: 0.0088
# Epoch 38: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6601 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0080 - learning_rate: 1.0000e-07
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.6606 - mae: 0.0087
# Epoch 39: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 315ms/step - loss: 0.6606 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.6596 - mae: 0.0090
# Epoch 40: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - loss: 0.6596 - mae: 0.0090 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 0.6600 - mae: 0.0087
# Epoch 41: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 331ms/step - loss: 0.6600 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.6604 - mae: 0.0087
# Epoch 42: val_loss improved from 0.66058 to 0.66058, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 325ms/step - loss: 0.6604 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.6603 - mae: 0.0088
# Epoch 43: val_loss improved from 0.66058 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 326ms/step - loss: 0.6603 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.6601 - mae: 0.0087
# Epoch 44: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - loss: 0.6601 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - loss: 0.6603 - mae: 0.0088
# Epoch 45: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 327ms/step - loss: 0.6603 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.6604 - mae: 0.0087
# Epoch 46: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 323ms/step - loss: 0.6604 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.6604 - mae: 0.0087
# Epoch 47: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 321ms/step - loss: 0.6604 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - loss: 0.6601 - mae: 0.0088
# Epoch 48: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - loss: 0.6601 - mae: 0.0088 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.6604 - mae: 0.0087
# Epoch 49: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 323ms/step - loss: 0.6604 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.6603 - mae: 0.0087
# Epoch 50: val_loss improved from 0.66057 to 0.66057, saving model to MobileNetV2_keypoints.weights.h5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - loss: 0.6603 - mae: 0.0087 - val_loss: 0.6606 - val_mae: 0.0079 - learning_rate: 1.0000e-07

# %%
# Generate predictions for all images in the validation set
checkpoint_filepath = "/kaggle/working/MobileNetV2_keypoints.weights.h5"
model.load_weights(checkpoint_filepath)

# %%
import random
import matplotlib.pyplot as plt

def plot_landmarks(image, landmarks, color=(255, 0, 0)):
    h, w, _ = image.shape
    radius = int(h * 0.005)
    for i in range(0, len(landmarks), 2):
        x = int(landmarks[i] * w)
        y = int(landmarks[i+1] * h)
        image = cv2.circle(image, (x, y), radius, color, -1)
    return image

# %%
def inference_fn(samples):
    plt.figure(figsize=(15, 8))
    
    for idx, (img_path, lm_path) in enumerate(samples, 1):
        # Original image
        image = cv2.imread(img_path, cv2.IMREAD_COLOR)
        h, w, _ = image.shape
    
        # Preprocess for model
        inp = cv2.resize(image, (image_w, image_h))
        inp = inp / 255.0
        inp = np.expand_dims(inp.astype(np.float32), axis=0)
    
        # Ground truth landmarks
        data = open(lm_path, "r").read()
        gt = []
        for line in data.strip().split("\n")[1:]:
            x, y = line.split(" ")
            x = float(x) / w
            y = float(y) / h
            gt.extend([x, y])
        gt = np.array(gt, dtype=np.float32)
    
        # Prediction
        pred = model.predict(inp, verbose=0)[0]
    
        # Draw
        gt_img = plot_landmarks(image.copy(), gt, color=(0, 255, 0))   # green = GT
        pred_img = plot_landmarks(image.copy(), pred, color=(0, 0, 255)) # red = Pred
    
        # Show side by side
        cat = np.concatenate([gt_img, pred_img], axis=1)
        cat = cv2.cvtColor(cat, cv2.COLOR_BGR2RGB)
    
        plt.subplot(2, 2, idx)
        plt.imshow(cat)
        plt.axis("off")
        plt.title(f"Sample {idx}: GT (left) vs Pred (right)")
    
    plt.tight_layout()
    plt.show()

# %%
img, gt = read_image_lankmarks(train_x[0], train_y[0])
pred = model.predict(img[np.newaxis], verbose=0)[0]
print("GT[0:10]:", gt[:10])
print("Pred[0:10]:", pred[:10])
# Out:
# GT[0:10]: [0.2159091  0.4817073  0.21789017 0.5009946  0.23057985 0.5219639
#  0.23595874 0.54120547 0.24564074 0.5642953 ]
# Pred[0:10]: [0.21682756 0.48171708 0.221831   0.5075725  0.2280455  0.52891976
#  0.23050196 0.5477813  0.24057071 0.5703055 ]

# %%
import matplotlib.pyplot as plt
fig, axis = plt.subplots(1, 2, figsize=(20, 5))
axis[0].plot(history.history["loss"], color='r', label = 'train loss')
axis[0].plot(history.history["val_loss"], color='b', label = 'val loss')
axis[0].set_title('Loss Comparison')
axis[0].legend()
axis[1].plot(history.history["mae"], color='r', label = 'train mae')
axis[1].plot(history.history["val_mae"], color='b', label = 'val_mae')
axis[1].set_title('mae Comparison')
axis[1].legend()

# %%
# Pick 4 random validation samples
samples = random.sample(list(zip(valid_x, valid_y)), 4)
inference_fn(samples)

# %%
samples = random.sample(list(zip(test_x, test_y)), 4)
inference_fn(samples)

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

def plot_landmarks(image, landmarks, color=(255, 0, 0)):
    h, w, _ = image.shape
    radius = max(1, int(h * 0.005))
    for i in range(0, len(landmarks), 2):
        x = int(landmarks[i] * w)
        y = int(landmarks[i+1] * h)
        image = cv2.circle(image, (x, y), radius, color, -1)
    return image

def inference_folder(folder, n_samples=4):
    # Collect only image files
    files = [f for f in os.listdir(folder) if f.lower().endswith((".jpg", ".png"))]
    samples = random.sample(files, min(n_samples, len(files)))

    rows = (len(samples) + 3) // 4   # ceiling division
    plt.figure(figsize=(15, 4 * rows))

    for idx, img_file in enumerate(samples, 1):
        img_path = os.path.join(folder, img_file)
        image = cv2.imread(img_path, cv2.IMREAD_COLOR)
        h, w, _ = image.shape

        # Preprocess for model
        inp = cv2.resize(image, (image_w, image_h))
        inp = inp / 255.0
        inp = np.expand_dims(inp.astype(np.float32), axis=0)

        # Prediction
        pred = model.predict(inp, verbose=0)[0]

        # Draw prediction only
        pred_img = plot_landmarks(image.copy(), pred, color=(0, 0, 255))
        pred_img = cv2.cvtColor(pred_img, cv2.COLOR_BGR2RGB)

        # Plot
        plt.subplot(rows, 4, idx)
        plt.imshow(pred_img)
        plt.axis("off")
        plt.title(f"Pred {idx}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# only 5 tests correct

# %%
# Run inference on face-tests/
inference_folder("/kaggle/input/face-tests/face-tests/", n_samples=12)

# %%
# Serialize the model as a SavedModel.
# Use model.export for Keras models
model.export("MobileNetV2_keypoints")

import tensorflow as tf
# Convert to TFLite. This form of quantization is called
# post-training dynamic-range quantization in TFLite.
converter = tf.lite.TFLiteConverter.from_saved_model("MobileNetV2_keypoints")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Enable TensorFlow Lite ops.
    tf.lite.OpsSet.SELECT_TF_OPS,  # Enable TensorFlow ops.
]
tflite_model = converter.convert()
open("MobileNetV2_keypoints.tflite", "wb").write(tflite_model)
# Out:
# Saved artifact at 'MobileNetV2_keypoints'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 212), dtype=tf.float32, name=None)
# Captures:
#   138876724521360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724522128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724517712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724520976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724522512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724521936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724520592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724520400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724517136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724521168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724521744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724520784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876724526928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627602512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627607312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627607696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627607888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627602704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627609232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627609616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627610000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627609808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627606160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627611152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627611536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627611920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627611728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627606928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627608848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627613648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627614032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627613840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627610384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627612688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627613264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841462736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627615376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876627614800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841463888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841464656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841463120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841466192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841466576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841466384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841463312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841467728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841468112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841468496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841468304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841462544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841469648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841470032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841470416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841465424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841471568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841471952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841472336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841472144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841467344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841473488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841473872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841474256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841474064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841475408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841475792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841476176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841475984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841477328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841477712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841478480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841477904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841473104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841463504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424359440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424358480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875841475024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424358672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424360976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424361744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424361552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424358864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424362896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424363280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424363664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424363472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424359824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424364816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424365584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424367120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424367504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424362512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424368656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424369040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424369424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424371344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424372496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424372880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424373264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424374416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424359248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556495824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875424372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556496976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556497360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556497552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556496208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556499280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556499664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556499472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556496400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556500816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556501200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556501392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556495632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556502736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556500432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556507152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556496592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557069840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557068880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875556508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557069072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557071376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557073296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557073680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557073872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557070224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557075216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557075600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557075792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557070992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557077136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557077520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557077904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557077712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557079056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557079440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557079824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557079632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557074832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557080976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557081360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557081744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557081552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557082896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557083280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557083664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557083472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557078672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557084816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557069648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366229008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557084432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875557082512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366229584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366229968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366230352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366230160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366228816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366231504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366231888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366232272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366232080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366228048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366233424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366233808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366234192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366234000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366228240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366235344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366235728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366236112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366235920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366231120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366237264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366237648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366238032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366237840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366233040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366239184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366239568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366239952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366239760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366234960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366241104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366241488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366241872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366241680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366236880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366243024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366243600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138875366238800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876645229200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138876645230544: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1759069215.901263      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1759069215.901305      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 1136696

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf

# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="/kaggle/working/MobileNetV2_keypoints.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Get input size (h, w, c)
input_shape = input_details[0]['shape'][1:3]

def plot_landmarks(image, landmarks, color=(255, 0, 0)):
    h, w, _ = image.shape
    radius = max(1, int(h * 0.005))
    for i in range(0, len(landmarks), 2):
        x = int(landmarks[i] * w)
        y = int(landmarks[i+1] * h)
        image = cv2.circle(image, (x, y), radius, color, -1)
    return image

def preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert("RGB").resize(target_size, Image.BILINEAR)
    arr = np.array(img, dtype=np.float32) / 255.0   # normalize
    return arr

def run_tflite_inference(img_path):
    img = preprocess_image(img_path, tuple(input_shape))
    inp = np.expand_dims(img, axis=0)  # [1,h,w,c]

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], inp)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])[0]

    return output  # already normalized landmark coords [x1,y1,...]

def inference_folder_tflite(folder, n_samples=4):
    files = [f for f in os.listdir(folder) if f.lower().endswith((".jpg", ".png"))]
    samples = random.sample(files, min(n_samples, len(files)))

    rows = (len(samples) + 3) // 4
    plt.figure(figsize=(15, 4 * rows))

    for idx, img_file in enumerate(samples, 1):
        img_path = os.path.join(folder, img_file)
        image = cv2.imread(img_path, cv2.IMREAD_COLOR)

        # Predict with TFLite model
        pred = run_tflite_inference(img_path)

        # Draw prediction
        pred_img = plot_landmarks(image.copy(), pred, color=(0, 0, 255))
        pred_img = cv2.cvtColor(pred_img, cv2.COLOR_BGR2RGB)

        plt.subplot(rows, 4, idx)
        plt.imshow(pred_img)
        plt.axis("off")
        plt.title(f"Pred {idx}")

    plt.tight_layout()
    plt.show()

# %%
# Example usage
inference_folder_tflite("/kaggle/input/face-tests/face-tests/", n_samples=12)
